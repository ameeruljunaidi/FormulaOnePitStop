# %%
# Import all the codes
# See pythoncodes.py in main folder for source code
import pythoncodes

# %% [markdown]
# **Available Codes**
#
# Copy paste the codes and execute.
#
# | Description | Code |
# | :- | :- |
# |View all available dataframes in original form|`pythoncodes.view_dataframes()`|
# |See an example of a figure of pit stops frequencies for all drivers for any particular race[<sup>1</sup>](#fn1)|`pythoncodes.fig_pit_example(raceId)`|
# |See average positional delta for all, control, and extra pitstops|`pythoncodes.view_delta()`|
# |See all regression results|`pythoncodes.view_reg()`|
# |See an example of lap time of a driver at a particular race[<sup>2</sup>](#fn2)|`pythoncodes.fig_laptime(raceId, driverId)`|
#
# ___
#
# [<sup id="fn1">1</sup>](#fn1-back) See `pythoncodes.max_pit.raceId.unique()` for all available raceIds.</span>
#
# [<sup id="fn2">2</sup>](#fn2-back) See `pythoncodes.max_pit.raceId.unique()` for all available raceIds and `pythoncodes.max_pit.driverId.unique()` for all available driverIds.</span>

# %%
# See pit stop frequencies for the first 5 races
for i in pythoncodes.max_pit.raceId.unique()[:5]:
    pythoncodes.fig_pit_example(i)
